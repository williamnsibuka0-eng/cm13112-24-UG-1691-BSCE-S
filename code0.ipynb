# %%
# Cell 1 - press Shift and Enter together to run it
print("Hello from CML3112")
print(2 + 2)

# Cell 2 - a variable is a name for a value
readings = 12
print(f"I have {readings} readings")


# Cell 3 - run THIS one three times and watch both numbers
readings = readings + 5
print(f"readings is now {readings}")
# Out:
# Hello from CML3112
# 4
# I have 12 readings
# readings is now 17
